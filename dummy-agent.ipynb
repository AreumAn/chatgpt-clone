# %%
from agents import Agent, Runner, function_tool, SQLiteSession

session = SQLiteSession("user_2", "ai-memory.db")


geaography_agent = Agent(
    name="Geo Expert Agent",
    instructions="You are a expert in geography, you answer questions related to them.",
    handoff_description="Use this to answer geography related questions.",
)
economics_agent = Agent(
    name="Economics Expert Agent",
    instructions="You are a expert in economics, you answer questions related to them.",
    handoff_description="Use this to answer economics questions.",
)

main_agent = Agent(
    name="Main Agent",
    instructions="You are a user facing agent. Transfer to the agent most capable of answering the user's question.",
    handoffs=[
        economics_agent,
        geaography_agent,
    ],
)

# %%
result = await Runner.run(
    main_agent,
    "Why do countries sell bonds?",
    session=session,
)

print(result.last_agent.name)
print(result.final_output)
# Out:
# Economics Expert Agent
# Countries sell bonds primarily to raise money for government spending that exceeds their current revenue from taxes and other sources. Here are the main reasons:
#
# 1. Financing Budget Deficits: If a government spends more than it collects in taxes and fees, it needs to borrow the difference. By issuing bonds (also called government securities), the government can borrow money from investors, both domestically and internationally.
#
# 2. Managing Monetary Policy: Central banks may buy or sell government bonds as part of open market operations to control money supply and interest rates.
#
# 3. Infrastructure and Investment: Governments may issue bonds to fund specific large-scale projects, such as building roads, airports, or hospitals.
#
# 4. Refinancing Existing Debt: Sometimes, governments issue new bonds to pay off maturing ones, effectively rolling over their debt.
#
# 5. Maintaining Liquidity: Issuing bonds can help a government manage its cash flow, ensuring it has enough funds to meet short-term obligations.
#
# In return for lending money by purchasing bonds, investors receive regular interest payments (coupon payments) and the return of their principal when the bonds mature. Government bonds are generally considered low-risk investments, depending on the financial health of the issuing country.
